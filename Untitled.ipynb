# %%
import numpy as np
import pandas as pd 
from importlib import reload
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import json
import random 
import time
from collections import deque

from src.Machine2 import Machine
from src.Job2 import Job
from src.Operation2 import Operation
from src.Agent2 import Agent
from src.Production_line2 import Production_line

import matplotlib.pyplot as plt


from tensorflow.keras import Model, Sequential
from tensorflow.keras.layers import Dense, Embedding, Reshape
from tensorflow.keras.optimizers import Adam

def dsp(data, rows=10, columns=None):
    
    pd.options.display.max_rows = rows
    pd.options.display.max_columns = columns

    display(data)

    pd.options.display.max_rows = 15
    pd.options.display.max_columns = 20

# %%
nbr_job_max = 3
nbr_operation_max = 14
nbr_machines = 14
nbr_operator = 12


batch_size = 1024

UPDATE_FREQ = 64
NETW_UPDATE_FREQ = 200
loop_number = 0


prod_line = Production_line(nbr_job_max, nbr_operation_max, nbr_machines, nbr_operator)
job1 = Job("TEST1", 1,20000, nbr_operation_max)
job2 = Job("TEST2", 1,20000, nbr_operation_max)
job3 = Job("TEST3", 1,20000, nbr_operation_max)

prod_line.add_job(job1)
prod_line.add_job(job2)
prod_line.add_job(job3)

agent = Agent(prod_line.state_size, len(prod_line.actions_space))
score_mean = deque(maxlen = 100)
to_plot = []

start = time.time()
n_episode = 1000

actions_space = prod_line.actions_space
for e in range(n_episode):
    prod_line = Production_line(nbr_job_max, nbr_operation_max, nbr_machines, nbr_operator)
    job1 = Job("TEST1", 1,20000, nbr_operation_max)
    job2 = Job("TEST2", 1,20000, nbr_operation_max)
    job3 = Job("TEST3", 1,20000, nbr_operation_max)

    prod_line.add_job(job1)
    prod_line.add_job(job2)
    prod_line.add_job(job3)
    
    state = prod_line.get_state()
    done = False
    score = 0
    
    while not done:
        mask = prod_line.get_mask()
        action = agent.act(state,mask)
        next_state, reward, done = prod_line.step(action)
        
        agent.remember(state, action, reward, next_state, done)
        
        state = next_state
            
        score += reward
        
        
        if loop_number % UPDATE_FREQ == 0 and loop_number > batch_size:
            agent.replay(batch_size)
            pass
            
        if loop_number % NETW_UPDATE_FREQ == 0:
            
            agent.alighn_target_model()
            
        loop_number += 1
        if done:
            print("episode : {}/{}, score : {}, e : {:.2}".format(e, n_episode, score, agent.epsilon))
            score_mean.append(score)
            break
            
    print("score mean over 100 episode : " ,np.mean(score_mean))
    to_plot.append(np.mean(score_mean))

print('It took', (time.time()-start)/n_episode, 'seconds.')
plt.plot(to_plot)
# Out:
# episode : 0/1000, score : -108, e : 1.0
# score mean over 100 episode :  -108.0
# episode : 1/1000, score : -82, e : 1.0
# score mean over 100 episode :  -95.0
# episode : 2/1000, score : -107, e : 1.0
# score mean over 100 episode :  -99.0
# episode : 3/1000, score : -104, e : 1.0
# score mean over 100 episode :  -100.25
# episode : 4/1000, score : -107, e : 1.0
# score mean over 100 episode :  -101.6
# episode : 5/1000, score : -97, e : 1.0
# score mean over 100 episode :  -100.83333333333333
# episode : 6/1000, score : -102, e : 1.0
# score mean over 100 episode :  -101.0
# episode : 7/1000, score : -100, e : 1.0
# score mean over 100 episode :  -100.875
# episode : 8/1000, score : -94, e : 1.0
# score mean over 100 episode :  -100.11111111111111
# episode : 9/1000, score : -107, e : 1.0
# score mean over 100 episode :  -100.8
# episode : 10/1000, score : -102, e : 1.0
# score mean over 100 episode :  -100.9090909090909
# episode : 11/1000, score : -105, e : 1.0
# score mean over 100 episode :  -101.25
# episode : 12/1000, score : -101, e : 1.0
# score mean over 100 episode :  -101.23076923076923
# episode : 13/1000, score : -103, e : 0.99
# score mean over 100 episode :  -101.35714285714286
# episode : 14/1000, score : -110, e : 0.99
# score mean over 100 episode :  -101.93333333333334
# episode : 15/1000, score : -111, e : 0.99
# score mean over 100 episode :  -102.5
# episode : 16/1000, score : -103, e : 0.99
# score mean over 100 episode :  -102.52941176470588
# episode : 17/1000, score : -118, e : 0.99
# score mean over 100 episode :  -103.38888888888889
# episode : 18/1000, score : -99, e : 0.99
# score mean over 100 episode :  -103.15789473684211
# episode : 19/1000, score : -107, e : 0.98
# score mean over 100 episode :  -103.35
# episode : 20/1000, score : -92, e : 0.98
# score mean over 100 episode :  -102.80952380952381
# episode : 21/1000, score : -116, e : 0.98
# score mean over 100 episode :  -103.4090909090909
# episode : 22/1000, score : -106, e : 0.98
# score mean over 100 episode :  -103.52173913043478
# episode : 23/1000, score : -88, e : 0.98
# score mean over 100 episode :  -102.875
# episode : 24/1000, score : -121, e : 0.98
# score mean over 100 episode :  -103.6
# episode : 25/1000, score : -83, e : 0.98
# score mean over 100 episode :  -102.8076923076923
# episode : 26/1000, score : -119, e : 0.97
# score mean over 100 episode :  -103.4074074074074
# episode : 27/1000, score : -108, e : 0.97
# score mean over 100 episode :  -103.57142857142857
# episode : 28/1000, score : -113, e : 0.97
# score mean over 100 episode :  -103.89655172413794
# episode : 29/1000, score : -125, e : 0.97
# score mean over 100 episode :  -104.6
# episode : 30/1000, score : -113, e : 0.97
# score mean over 100 episode :  -104.87096774193549
# episode : 31/1000, score : -104, e : 0.96
# score mean over 100 episode :  -104.84375
# episode : 32/1000, score : -100, e : 0.96
# score mean over 100 episode :  -104.6969696969697
# episode : 33/1000, score : -100, e : 0.96
# score mean over 100 episode :  -104.55882352941177
# episode : 34/1000, score : -118, e : 0.96
# score mean over 100 episode :  -104.94285714285714
# episode : 35/1000, score : -96, e : 0.96
# score mean over 100 episode :  -104.69444444444444
# episode : 36/1000, score : -101, e : 0.96
# score mean over 100 episode :  -104.5945945945946
# episode : 37/1000, score : -112, e : 0.96
# score mean over 100 episode :  -104.78947368421052
# episode : 38/1000, score : -115, e : 0.95
# score mean over 100 episode :  -105.05128205128206
# episode : 39/1000, score : -97, e : 0.95
# score mean over 100 episode :  -104.85
# episode : 40/1000, score : -94, e : 0.95
# score mean over 100 episode :  -104.58536585365853
# episode : 41/1000, score : -92, e : 0.95
# score mean over 100 episode :  -104.28571428571429
# episode : 42/1000, score : -105, e : 0.95
# score mean over 100 episode :  -104.30232558139535
# episode : 43/1000, score : -107, e : 0.95
# score mean over 100 episode :  -104.36363636363636
# episode : 44/1000, score : -112, e : 0.94
# score mean over 100 episode :  -104.53333333333333
# episode : 45/1000, score : -95, e : 0.94
# score mean over 100 episode :  -104.32608695652173
# episode : 46/1000, score : -98, e : 0.94
# score mean over 100 episode :  -104.19148936170212
# episode : 47/1000, score : -105, e : 0.94
# score mean over 100 episode :  -104.20833333333333
# episode : 48/1000, score : -108, e : 0.94
# score mean over 100 episode :  -104.28571428571429
# episode : 49/1000, score : -113, e : 0.94
# score mean over 100 episode :  -104.46
# episode : 50/1000, score : -107, e : 0.94
# score mean over 100 episode :  -104.50980392156863
# episode : 51/1000, score : -98, e : 0.93
# score mean over 100 episode :  -104.38461538461539
# episode : 52/1000, score : -108, e : 0.93
# score mean over 100 episode :  -104.45283018867924
# episode : 53/1000, score : -128, e : 0.93
# score mean over 100 episode :  -104.88888888888889
# episode : 54/1000, score : -111, e : 0.93
# score mean over 100 episode :  -105.0
# episode : 55/1000, score : -94, e : 0.93
# score mean over 100 episode :  -104.80357142857143
# episode : 56/1000, score : -114, e : 0.93
# score mean over 100 episode :  -104.96491228070175
# episode : 57/1000, score : -96, e : 0.92
# score mean over 100 episode :  -104.8103448275862
# episode : 58/1000, score : -102, e : 0.92
# score mean over 100 episode :  -104.76271186440678
# episode : 59/1000, score : -126, e : 0.92
# score mean over 100 episode :  -105.11666666666666
# episode : 60/1000, score : -114, e : 0.92
# score mean over 100 episode :  -105.26229508196721
# episode : 61/1000, score : -93, e : 0.92
# score mean over 100 episode :  -105.06451612903226
# episode : 62/1000, score : -114, e : 0.92
# score mean over 100 episode :  -105.2063492063492
# episode : 63/1000, score : -98, e : 0.91
# score mean over 100 episode :  -105.09375
# episode : 64/1000, score : -91, e : 0.91
# score mean over 100 episode :  -104.87692307692308
# episode : 65/1000, score : -116, e : 0.91
# score mean over 100 episode :  -105.04545454545455
# episode : 66/1000, score : -103, e : 0.91
# score mean over 100 episode :  -105.01492537313433
# episode : 67/1000, score : -107, e : 0.91
# score mean over 100 episode :  -105.04411764705883
# episode : 68/1000, score : -108, e : 0.91
# score mean over 100 episode :  -105.08695652173913
# episode : 69/1000, score : -101, e : 0.91
# score mean over 100 episode :  -105.02857142857142
# episode : 70/1000, score : -133, e : 0.9
# score mean over 100 episode :  -105.4225352112676
# episode : 71/1000, score : -115, e : 0.9
# score mean over 100 episode :  -105.55555555555556
# episode : 72/1000, score : -101, e : 0.9
# score mean over 100 episode :  -105.4931506849315
# episode : 73/1000, score : -119, e : 0.9
# score mean over 100 episode :  -105.67567567567568
# episode : 74/1000, score : -103, e : 0.9
# score mean over 100 episode :  -105.64
# episode : 75/1000, score : -106, e : 0.9
# score mean over 100 episode :  -105.64473684210526
# episode : 76/1000, score : -98, e : 0.9
# score mean over 100 episode :  -105.54545454545455
# episode : 77/1000, score : -134, e : 0.89
# score mean over 100 episode :  -105.91025641025641
# episode : 78/1000, score : -125, e : 0.89
# score mean over 100 episode :  -106.15189873417721
# episode : 79/1000, score : -119, e : 0.89
# score mean over 100 episode :  -106.3125
# episode : 80/1000, score : -105, e : 0.89
# score mean over 100 episode :  -106.29629629629629
# episode : 81/1000, score : -104, e : 0.89
# score mean over 100 episode :  -106.26829268292683
# episode : 82/1000, score : -130, e : 0.89
# score mean over 100 episode :  -106.55421686746988
# episode : 83/1000, score : -126, e : 0.88
# score mean over 100 episode :  -106.78571428571429
# episode : 84/1000, score : -122, e : 0.88
# score mean over 100 episode :  -106.96470588235294
# episode : 85/1000, score : -118, e : 0.88
# score mean over 100 episode :  -107.09302325581395
# episode : 86/1000, score : -119, e : 0.88
# score mean over 100 episode :  -107.22988505747126
# episode : 87/1000, score : -118, e : 0.88
# score mean over 100 episode :  -107.35227272727273
# episode : 88/1000, score : -119, e : 0.88
# score mean over 100 episode :  -107.48314606741573
# episode : 89/1000, score : -116, e : 0.87
# score mean over 100 episode :  -107.57777777777778
# episode : 90/1000, score : -106, e : 0.87
# score mean over 100 episode :  -107.56043956043956
# episode : 91/1000, score : -113, e : 0.87
# score mean over 100 episode :  -107.6195652173913
# episode : 92/1000, score : -121, e : 0.87
# score mean over 100 episode :  -107.76344086021506
# episode : 93/1000, score : -121, e : 0.87
# score mean over 100 episode :  -107.90425531914893
# episode : 94/1000, score : -126, e : 0.87
# score mean over 100 episode :  -108.09473684210526
# episode : 95/1000, score : -122, e : 0.86
# score mean over 100 episode :  -108.23958333333333
# episode : 96/1000, score : -109, e : 0.86
# score mean over 100 episode :  -108.24742268041237
# episode : 97/1000, score : -108, e : 0.86
# score mean over 100 episode :  -108.24489795918367
# episode : 98/1000, score : -115, e : 0.86
# score mean over 100 episode :  -108.31313131313131
# episode : 99/1000, score : -124, e : 0.86
# score mean over 100 episode :  -108.47
# episode : 100/1000, score : -113, e : 0.86
# score mean over 100 episode :  -108.52
# episode : 101/1000, score : -102, e : 0.86
# score mean over 100 episode :  -108.72
# episode : 102/1000, score : -112, e : 0.85
# score mean over 100 episode :  -108.77
# episode : 103/1000, score : -114, e : 0.85
# score mean over 100 episode :  -108.87
# episode : 104/1000, score : -132, e : 0.85
# score mean over 100 episode :  -109.12
# episode : 105/1000, score : -114, e : 0.85
# score mean over 100 episode :  -109.29
# episode : 106/1000, score : -136, e : 0.85
# score mean over 100 episode :  -109.63
# episode : 107/1000, score : -128, e : 0.85
# score mean over 100 episode :  -109.91
# episode : 108/1000, score : -112, e : 0.84
# score mean over 100 episode :  -110.09
# episode : 109/1000, score : -116, e : 0.84
# score mean over 100 episode :  -110.18
# episode : 110/1000, score : -108, e : 0.84
# score mean over 100 episode :  -110.24
# episode : 111/1000, score : -132, e : 0.84
# score mean over 100 episode :  -110.51
# episode : 112/1000, score : -146, e : 0.84
# score mean over 100 episode :  -110.96
# episode : 113/1000, score : -126, e : 0.84
# score mean over 100 episode :  -111.19
# episode : 114/1000, score : -111, e : 0.83
# score mean over 100 episode :  -111.2
# episode : 115/1000, score : -133, e : 0.83
# score mean over 100 episode :  -111.42
# episode : 116/1000, score : -110, e : 0.83
# score mean over 100 episode :  -111.49
# episode : 117/1000, score : -127, e : 0.83
# score mean over 100 episode :  -111.58
# episode : 118/1000, score : -131, e : 0.83
# score mean over 100 episode :  -111.9
# episode : 119/1000, score : -104, e : 0.83
# score mean over 100 episode :  -111.87
# episode : 120/1000, score : -126, e : 0.82
# score mean over 100 episode :  -112.21
# episode : 121/1000, score : -116, e : 0.82
# score mean over 100 episode :  -112.21
# episode : 122/1000, score : -145, e : 0.82
# score mean over 100 episode :  -112.6
# episode : 123/1000, score : -118, e : 0.82
# score mean over 100 episode :  -112.9
# episode : 124/1000, score : -122, e : 0.82
# score mean over 100 episode :  -112.91
# episode : 125/1000, score : -111, e : 0.82
# score mean over 100 episode :  -113.19
# episode : 126/1000, score : -140, e : 0.82
# score mean over 100 episode :  -113.4
# episode : 127/1000, score : -137, e : 0.81
# score mean over 100 episode :  -113.69
# episode : 128/1000, score : -118, e : 0.81
# score mean over 100 episode :  -113.74
# episode : 129/1000, score : -127, e : 0.81
# score mean over 100 episode :  -113.76
# episode : 130/1000, score : -111, e : 0.81
# score mean over 100 episode :  -113.74
# episode : 131/1000, score : -109, e : 0.81
# score mean over 100 episode :  -113.79
# episode : 132/1000, score : -145, e : 0.81
# score mean over 100 episode :  -114.24
# episode : 133/1000, score : -127, e : 0.8
# score mean over 100 episode :  -114.51
# episode : 134/1000, score : -134, e : 0.8
# score mean over 100 episode :  -114.67
# episode : 135/1000, score : -131, e : 0.8
# score mean over 100 episode :  -115.02
# episode : 136/1000, score : -148, e : 0.8
# score mean over 100 episode :  -115.49
# episode : 137/1000, score : -144, e : 0.8
# score mean over 100 episode :  -115.81
# episode : 138/1000, score : -111, e : 0.8
# score mean over 100 episode :  -115.77
# episode : 139/1000, score : -132, e : 0.79
# score mean over 100 episode :  -116.12
# episode : 140/1000, score : -122, e : 0.79
# score mean over 100 episode :  -116.4
# episode : 141/1000, score : -130, e : 0.79
# score mean over 100 episode :  -116.78
# episode : 142/1000, score : -127, e : 0.79
# score mean over 100 episode :  -117.0
# episode : 143/1000, score : -144, e : 0.79
# score mean over 100 episode :  -117.37
# episode : 144/1000, score : -113, e : 0.79
# score mean over 100 episode :  -117.38
# episode : 145/1000, score : -124, e : 0.78
# score mean over 100 episode :  -117.67
# episode : 146/1000, score : -151, e : 0.78
# score mean over 100 episode :  -118.2
# episode : 147/1000, score : -145, e : 0.78
# score mean over 100 episode :  -118.6
# episode : 148/1000, score : -142, e : 0.78
# score mean over 100 episode :  -118.94
# episode : 149/1000, score : -116, e : 0.78
# score mean over 100 episode :  -118.97
# episode : 150/1000, score : -119, e : 0.78
# score mean over 100 episode :  -119.09
# episode : 151/1000, score : -136, e : 0.77
# score mean over 100 episode :  -119.47
# episode : 152/1000, score : -149, e : 0.77
# score mean over 100 episode :  -119.88
# episode : 153/1000, score : -143, e : 0.77
# score mean over 100 episode :  -120.03
# episode : 154/1000, score : -122, e : 0.77
# score mean over 100 episode :  -120.14
# episode : 155/1000, score : -144, e : 0.77
# score mean over 100 episode :  -120.64
# episode : 156/1000, score : -129, e : 0.77
# score mean over 100 episode :  -120.79
# episode : 157/1000, score : -139, e : 0.76
# score mean over 100 episode :  -121.22
# episode : 158/1000, score : -121, e : 0.76
# score mean over 100 episode :  -121.41
# episode : 159/1000, score : -136, e : 0.76
# score mean over 100 episode :  -121.51
# episode : 160/1000, score : -125, e : 0.76
# score mean over 100 episode :  -121.62
# episode : 161/1000, score : -133, e : 0.76
# score mean over 100 episode :  -122.02
# episode : 162/1000, score : -142, e : 0.76
# score mean over 100 episode :  -122.3
# episode : 163/1000, score : -122, e : 0.76
# score mean over 100 episode :  -122.54
# episode : 164/1000, score : -145, e : 0.75
# score mean over 100 episode :  -123.08
# episode : 165/1000, score : -125, e : 0.75
# score mean over 100 episode :  -123.17
# episode : 166/1000, score : -131, e : 0.75
# score mean over 100 episode :  -123.45
# episode : 167/1000, score : -138, e : 0.75
# score mean over 100 episode :  -123.76
# episode : 168/1000, score : -156, e : 0.75
# score mean over 100 episode :  -124.24
# episode : 169/1000, score : -120, e : 0.75
# score mean over 100 episode :  -124.43
# episode : 170/1000, score : -139, e : 0.74
# score mean over 100 episode :  -124.49
# episode : 171/1000, score : -145, e : 0.74
# score mean over 100 episode :  -124.79
# episode : 172/1000, score : -140, e : 0.74
# score mean over 100 episode :  -125.18
# episode : 173/1000, score : -116, e : 0.74
# score mean over 100 episode :  -125.15
# episode : 174/1000, score : -144, e : 0.74
# score mean over 100 episode :  -125.56
# episode : 175/1000, score : -146, e : 0.74
# score mean over 100 episode :  -125.96
# episode : 176/1000, score : -152, e : 0.73
# score mean over 100 episode :  -126.5
# episode : 177/1000, score : -146, e : 0.73
# score mean over 100 episode :  -126.62
# episode : 178/1000, score : -128, e : 0.73
# score mean over 100 episode :  -126.65
# episode : 179/1000, score : -163, e : 0.73
# score mean over 100 episode :  -127.09
# episode : 180/1000, score : -170, e : 0.73
# score mean over 100 episode :  -127.74
# episode : 181/1000, score : -158, e : 0.73
# score mean over 100 episode :  -128.28
# episode : 182/1000, score : -134, e : 0.72
# score mean over 100 episode :  -128.32
# episode : 183/1000, score : -137, e : 0.72
# score mean over 100 episode :  -128.43
# episode : 184/1000, score : -157, e : 0.72
# score mean over 100 episode :  -128.78
# episode : 185/1000, score : -130, e : 0.72
# score mean over 100 episode :  -128.9
# episode : 186/1000, score : -146, e : 0.72
# score mean over 100 episode :  -129.17
# episode : 187/1000, score : -142, e : 0.72
# score mean over 100 episode :  -129.41
# episode : 188/1000, score : -151, e : 0.71
# score mean over 100 episode :  -129.73
# episode : 189/1000, score : -145, e : 0.71
# score mean over 100 episode :  -130.02
# episode : 190/1000, score : -159, e : 0.71
# score mean over 100 episode :  -130.55
# episode : 191/1000, score : -145, e : 0.71
# score mean over 100 episode :  -130.87
# episode : 192/1000, score : -140, e : 0.71
# score mean over 100 episode :  -131.06
# episode : 193/1000, score : -148, e : 0.71
# score mean over 100 episode :  -131.33
# episode : 194/1000, score : -137, e : 0.71
# score mean over 100 episode :  -131.44
# episode : 195/1000, score : -136, e : 0.7
# score mean over 100 episode :  -131.58
# episode : 196/1000, score : -149, e : 0.7
# score mean over 100 episode :  -131.98
# episode : 197/1000, score : -151, e : 0.7
# score mean over 100 episode :  -132.41
# episode : 198/1000, score : -139, e : 0.7
# score mean over 100 episode :  -132.65
# episode : 199/1000, score : -144, e : 0.7
# score mean over 100 episode :  -132.85
# episode : 200/1000, score : -150, e : 0.7
# score mean over 100 episode :  -133.22
# episode : 201/1000, score : -151, e : 0.69
# score mean over 100 episode :  -133.71
# episode : 202/1000, score : -149, e : 0.69
# score mean over 100 episode :  -134.08
# episode : 203/1000, score : -126, e : 0.69
# score mean over 100 episode :  -134.2
# episode : 204/1000, score : -176, e : 0.69
# score mean over 100 episode :  -134.64
# episode : 205/1000, score : -133, e : 0.69
# score mean over 100 episode :  -134.83
# episode : 206/1000, score : -161, e : 0.69
# score mean over 100 episode :  -135.08
# episode : 207/1000, score : -196, e : 0.68
# score mean over 100 episode :  -135.76
# episode : 208/1000, score : -150, e : 0.68
# score mean over 100 episode :  -136.14
# episode : 209/1000, score : -139, e : 0.68
# score mean over 100 episode :  -136.37
# episode : 210/1000, score : -153, e : 0.68
# score mean over 100 episode :  -136.82
# episode : 211/1000, score : -135, e : 0.68
# score mean over 100 episode :  -136.85
# episode : 212/1000, score : -141, e : 0.68
# score mean over 100 episode :  -136.8
# episode : 213/1000, score : -166, e : 0.67
# score mean over 100 episode :  -137.2
# episode : 214/1000, score : -129, e : 0.67
# score mean over 100 episode :  -137.38
# episode : 215/1000, score : -143, e : 0.67
# score mean over 100 episode :  -137.48
# episode : 216/1000, score : -160, e : 0.67
# score mean over 100 episode :  -137.98
# episode : 217/1000, score : -137, e : 0.67
# score mean over 100 episode :  -138.08
# episode : 218/1000, score : -153, e : 0.67
# score mean over 100 episode :  -138.3
# episode : 219/1000, score : -147, e : 0.67
# score mean over 100 episode :  -138.73
# episode : 220/1000, score : -145, e : 0.66
# score mean over 100 episode :  -138.92
# episode : 221/1000, score : -137, e : 0.66
# score mean over 100 episode :  -139.13
# episode : 222/1000, score : -187, e : 0.66
# score mean over 100 episode :  -139.55
# episode : 223/1000, score : -154, e : 0.66
# score mean over 100 episode :  -139.91
# episode : 224/1000, score : -146, e : 0.66
# score mean over 100 episode :  -140.15
# episode : 225/1000, score : -191, e : 0.66
# score mean over 100 episode :  -140.95
# episode : 226/1000, score : -177, e : 0.65
# score mean over 100 episode :  -141.32
# episode : 227/1000, score : -163, e : 0.65
# score mean over 100 episode :  -141.58
# episode : 228/1000, score : -166, e : 0.65
# score mean over 100 episode :  -142.06
# episode : 229/1000, score : -142, e : 0.65
# score mean over 100 episode :  -142.21
# episode : 230/1000, score : -163, e : 0.65
# score mean over 100 episode :  -142.73
# episode : 231/1000, score : -152, e : 0.65
# score mean over 100 episode :  -143.16
# episode : 232/1000, score : -141, e : 0.64
# score mean over 100 episode :  -143.12
# episode : 233/1000, score : -154, e : 0.64
# score mean over 100 episode :  -143.39
# episode : 234/1000, score : -140, e : 0.64
# score mean over 100 episode :  -143.45
# episode : 235/1000, score : -139, e : 0.64
# score mean over 100 episode :  -143.53
# episode : 236/1000, score : -181, e : 0.64
# score mean over 100 episode :  -143.86
# episode : 237/1000, score : -204, e : 0.64
# score mean over 100 episode :  -144.46
# episode : 238/1000, score : -132, e : 0.63
# score mean over 100 episode :  -144.67
# episode : 239/1000, score : -174, e : 0.63
# score mean over 100 episode :  -145.09
# episode : 240/1000, score : -167, e : 0.63
# score mean over 100 episode :  -145.54
# episode : 241/1000, score : -177, e : 0.63
# score mean over 100 episode :  -146.01
# episode : 242/1000, score : -162, e : 0.63
# score mean over 100 episode :  -146.36
# episode : 243/1000, score : -157, e : 0.63
# score mean over 100 episode :  -146.49
# episode : 244/1000, score : -169, e : 0.62
# score mean over 100 episode :  -147.05
# episode : 245/1000, score : -152, e : 0.62
# score mean over 100 episode :  -147.33
# episode : 246/1000, score : -151, e : 0.62
# score mean over 100 episode :  -147.33
# episode : 247/1000, score : -146, e : 0.62
# score mean over 100 episode :  -147.34
# episode : 248/1000, score : -158, e : 0.62
# score mean over 100 episode :  -147.5
# episode : 249/1000, score : -158, e : 0.62
# score mean over 100 episode :  -147.92
# episode : 250/1000, score : -182, e : 0.62
# score mean over 100 episode :  -148.55
# episode : 251/1000, score : -176, e : 0.61
# score mean over 100 episode :  -148.95
# episode : 252/1000, score : -148, e : 0.61
# score mean over 100 episode :  -148.94
# episode : 253/1000, score : -166, e : 0.61
# score mean over 100 episode :  -149.17
# episode : 254/1000, score : -156, e : 0.61
# score mean over 100 episode :  -149.51
# episode : 255/1000, score : -196, e : 0.61
# score mean over 100 episode :  -150.03
# episode : 256/1000, score : -173, e : 0.61
# score mean over 100 episode :  -150.47
# episode : 257/1000, score : -170, e : 0.6
# score mean over 100 episode :  -150.78
# episode : 258/1000, score : -151, e : 0.6
# score mean over 100 episode :  -151.08
# episode : 259/1000, score : -169, e : 0.6
# score mean over 100 episode :  -151.41
# episode : 260/1000, score : -153, e : 0.6
# score mean over 100 episode :  -151.69
# episode : 261/1000, score : -200, e : 0.6
# score mean over 100 episode :  -152.36
# episode : 262/1000, score : -157, e : 0.6
# score mean over 100 episode :  -152.51
# episode : 263/1000, score : -189, e : 0.59
# score mean over 100 episode :  -153.18
# episode : 264/1000, score : -195, e : 0.59
# score mean over 100 episode :  -153.68
# episode : 265/1000, score : -159, e : 0.59
# score mean over 100 episode :  -154.02
# episode : 266/1000, score : -197, e : 0.59
# score mean over 100 episode :  -154.68
# episode : 267/1000, score : -153, e : 0.59
# score mean over 100 episode :  -154.83
# episode : 268/1000, score : -168, e : 0.59
# score mean over 100 episode :  -154.95
# episode : 269/1000, score : -154, e : 0.59
# score mean over 100 episode :  -155.29
# episode : 270/1000, score : -204, e : 0.58
# score mean over 100 episode :  -155.94
# episode : 271/1000, score : -173, e : 0.58
# score mean over 100 episode :  -156.22
# episode : 272/1000, score : -208, e : 0.58
# score mean over 100 episode :  -156.9
# episode : 273/1000, score : -212, e : 0.58
# score mean over 100 episode :  -157.86
# episode : 274/1000, score : -177, e : 0.58
# score mean over 100 episode :  -158.19
# episode : 275/1000, score : -179, e : 0.58
# score mean over 100 episode :  -158.52
# episode : 276/1000, score : -191, e : 0.57
# score mean over 100 episode :  -158.91
# episode : 277/1000, score : -222, e : 0.57
# score mean over 100 episode :  -159.67
# episode : 278/1000, score : -164, e : 0.57
# score mean over 100 episode :  -160.03
# episode : 279/1000, score : -195, e : 0.57
# score mean over 100 episode :  -160.35
# episode : 280/1000, score : -208, e : 0.57
# score mean over 100 episode :  -160.73
# episode : 281/1000, score : -156, e : 0.56
# score mean over 100 episode :  -160.71
# episode : 282/1000, score : -195, e : 0.56
# score mean over 100 episode :  -161.32
# episode : 283/1000, score : -172, e : 0.56
# score mean over 100 episode :  -161.67
# episode : 284/1000, score : -169, e : 0.56
# score mean over 100 episode :  -161.79
# episode : 285/1000, score : -209, e : 0.56
# score mean over 100 episode :  -162.58
# episode : 286/1000, score : -184, e : 0.56
# score mean over 100 episode :  -162.96
# episode : 287/1000, score : -168, e : 0.56
# score mean over 100 episode :  -163.22
# episode : 288/1000, score : -205, e : 0.55
# score mean over 100 episode :  -163.76
# episode : 289/1000, score : -202, e : 0.55
# score mean over 100 episode :  -164.33
# episode : 290/1000, score : -180, e : 0.55
# score mean over 100 episode :  -164.54
# episode : 291/1000, score : -184, e : 0.55
# score mean over 100 episode :  -164.93
# episode : 292/1000, score : -167, e : 0.55
# score mean over 100 episode :  -165.2
# episode : 293/1000, score : -149, e : 0.55
# score mean over 100 episode :  -165.21
# episode : 294/1000, score : -190, e : 0.54
# score mean over 100 episode :  -165.74
# episode : 295/1000, score : -170, e : 0.54
# score mean over 100 episode :  -166.08
# episode : 296/1000, score : -182, e : 0.54
# score mean over 100 episode :  -166.41
# episode : 297/1000, score : -226, e : 0.54
# score mean over 100 episode :  -167.16
# episode : 298/1000, score : -225, e : 0.54
# score mean over 100 episode :  -168.02
# episode : 299/1000, score : -192, e : 0.54
# score mean over 100 episode :  -168.5
# episode : 300/1000, score : -182, e : 0.53
# score mean over 100 episode :  -168.82
# episode : 301/1000, score : -204, e : 0.53
# score mean over 100 episode :  -169.35
# episode : 302/1000, score : -199, e : 0.53
# score mean over 100 episode :  -169.85
# episode : 303/1000, score : -170, e : 0.53
# score mean over 100 episode :  -170.29
# episode : 304/1000, score : -216, e : 0.53
# score mean over 100 episode :  -170.69
# episode : 305/1000, score : -162, e : 0.53
# score mean over 100 episode :  -170.98
# episode : 306/1000, score : -193, e : 0.52
# score mean over 100 episode :  -171.3
# episode : 307/1000, score : -197, e : 0.52
# score mean over 100 episode :  -171.31
# episode : 308/1000, score : -184, e : 0.52
# score mean over 100 episode :  -171.65
# episode : 309/1000, score : -211, e : 0.52
# score mean over 100 episode :  -172.37
# episode : 310/1000, score : -210, e : 0.52
# score mean over 100 episode :  -172.94
# episode : 311/1000, score : -158, e : 0.52
# score mean over 100 episode :  -173.17
# episode : 312/1000, score : -179, e : 0.52
# score mean over 100 episode :  -173.55
# episode : 313/1000, score : -203, e : 0.51
# score mean over 100 episode :  -173.92
# episode : 314/1000, score : -207, e : 0.51
# score mean over 100 episode :  -174.7
# episode : 315/1000, score : -159, e : 0.51
# score mean over 100 episode :  -174.86
# episode : 316/1000, score : -165, e : 0.51
# score mean over 100 episode :  -174.91
# episode : 317/1000, score : -225, e : 0.51
# score mean over 100 episode :  -175.79
# episode : 318/1000, score : -189, e : 0.51
# score mean over 100 episode :  -176.15
# episode : 319/1000, score : -171, e : 0.5
# score mean over 100 episode :  -176.39
# episode : 320/1000, score : -182, e : 0.5
# score mean over 100 episode :  -176.76
# episode : 321/1000, score : -265, e : 0.5
# score mean over 100 episode :  -178.04
# episode : 322/1000, score : -208, e : 0.5
# score mean over 100 episode :  -178.25
# episode : 323/1000, score : -162, e : 0.5
# score mean over 100 episode :  -178.33
# episode : 324/1000, score : -188, e : 0.5
# score mean over 100 episode :  -178.75
# episode : 325/1000, score : -210, e : 0.5
# score mean over 100 episode :  -178.94
# episode : 326/1000, score : -210, e : 0.49
# score mean over 100 episode :  -179.27
# episode : 327/1000, score : -222, e : 0.49
# score mean over 100 episode :  -179.86
# episode : 328/1000, score : -220, e : 0.49
# score mean over 100 episode :  -180.4
# episode : 329/1000, score : -186, e : 0.49
# score mean over 100 episode :  -180.84
# episode : 330/1000, score : -193, e : 0.49
# score mean over 100 episode :  -181.14
# episode : 331/1000, score : -184, e : 0.49
# score mean over 100 episode :  -181.46
# episode : 332/1000, score : -229, e : 0.48
# score mean over 100 episode :  -182.34
# episode : 333/1000, score : -215, e : 0.48
# score mean over 100 episode :  -182.95
# episode : 334/1000, score : -231, e : 0.48
# score mean over 100 episode :  -183.86
# episode : 335/1000, score : -232, e : 0.48
# score mean over 100 episode :  -184.79
# episode : 336/1000, score : -222, e : 0.48
# score mean over 100 episode :  -185.2
# episode : 337/1000, score : -200, e : 0.48
# score mean over 100 episode :  -185.16
# episode : 338/1000, score : -184, e : 0.47
# score mean over 100 episode :  -185.68
# episode : 339/1000, score : -233, e : 0.47
# score mean over 100 episode :  -186.27
# episode : 340/1000, score : -234, e : 0.47
# score mean over 100 episode :  -186.94
# episode : 341/1000, score : -213, e : 0.47
# score mean over 100 episode :  -187.3
# episode : 342/1000, score : -208, e : 0.47
# score mean over 100 episode :  -187.76
# episode : 343/1000, score : -212, e : 0.47
# score mean over 100 episode :  -188.31
# episode : 344/1000, score : -193, e : 0.47
# score mean over 100 episode :  -188.55
# episode : 345/1000, score : -253, e : 0.46
# score mean over 100 episode :  -189.56
# episode : 346/1000, score : -194, e : 0.46
# score mean over 100 episode :  -189.99
# episode : 347/1000, score : -170, e : 0.46
# score mean over 100 episode :  -190.23
# episode : 348/1000, score : -245, e : 0.46
# score mean over 100 episode :  -191.1
# episode : 349/1000, score : -239, e : 0.46
# score mean over 100 episode :  -191.91
# episode : 350/1000, score : -255, e : 0.46
# score mean over 100 episode :  -192.64
# episode : 351/1000, score : -207, e : 0.45
# score mean over 100 episode :  -192.95
# episode : 352/1000, score : -196, e : 0.45
# score mean over 100 episode :  -193.43
# episode : 353/1000, score : -202, e : 0.45
# score mean over 100 episode :  -193.79
# episode : 354/1000, score : -238, e : 0.45
# score mean over 100 episode :  -194.61
# episode : 355/1000, score : -265, e : 0.45
# score mean over 100 episode :  -195.3
# episode : 356/1000, score : -260, e : 0.45
# score mean over 100 episode :  -196.17
# episode : 357/1000, score : -223, e : 0.44
# score mean over 100 episode :  -196.7
# episode : 358/1000, score : -207, e : 0.44
# score mean over 100 episode :  -197.26
# episode : 359/1000, score : -209, e : 0.44
# score mean over 100 episode :  -197.66
# episode : 360/1000, score : -211, e : 0.44
# score mean over 100 episode :  -198.24
# episode : 361/1000, score : -190, e : 0.44
# score mean over 100 episode :  -198.14
# episode : 362/1000, score : -296, e : 0.44
# score mean over 100 episode :  -199.53
# episode : 363/1000, score : -218, e : 0.43
# score mean over 100 episode :  -199.82
# episode : 364/1000, score : -248, e : 0.43
# score mean over 100 episode :  -200.35
# episode : 365/1000, score : -205, e : 0.43
# score mean over 100 episode :  -200.81
# episode : 366/1000, score : -226, e : 0.43
# score mean over 100 episode :  -201.1
# episode : 367/1000, score : -210, e : 0.43
# score mean over 100 episode :  -201.67
# episode : 368/1000, score : -238, e : 0.43
# score mean over 100 episode :  -202.37
# episode : 369/1000, score : -203, e : 0.43
# score mean over 100 episode :  -202.86
# episode : 370/1000, score : -231, e : 0.42
# score mean over 100 episode :  -203.13
# episode : 371/1000, score : -290, e : 0.42
# score mean over 100 episode :  -204.3
# episode : 372/1000, score : -236, e : 0.42
# score mean over 100 episode :  -204.58
# episode : 373/1000, score : -216, e : 0.42
# score mean over 100 episode :  -204.62
# episode : 374/1000, score : -206, e : 0.42
# score mean over 100 episode :  -204.91
# episode : 375/1000, score : -251, e : 0.42
# score mean over 100 episode :  -205.63
# episode : 376/1000, score : -273, e : 0.42
# score mean over 100 episode :  -206.45
# episode : 377/1000, score : -232, e : 0.41
# score mean over 100 episode :  -206.55
# episode : 378/1000, score : -248, e : 0.41
# score mean over 100 episode :  -207.39
# episode : 379/1000, score : -217, e : 0.41
# score mean over 100 episode :  -207.61
# episode : 380/1000, score : -262, e : 0.41
# score mean over 100 episode :  -208.15
# episode : 381/1000, score : -220, e : 0.41
# score mean over 100 episode :  -208.79
# episode : 382/1000, score : -251, e : 0.41
# score mean over 100 episode :  -209.35
# episode : 383/1000, score : -262, e : 0.4
# score mean over 100 episode :  -210.25
# episode : 384/1000, score : -266, e : 0.4
# score mean over 100 episode :  -211.22
# episode : 385/1000, score : -261, e : 0.4
# score mean over 100 episode :  -211.74
# episode : 386/1000, score : -262, e : 0.4
# score mean over 100 episode :  -212.52
# episode : 387/1000, score : -259, e : 0.4
# score mean over 100 episode :  -213.43
# episode : 388/1000, score : -269, e : 0.4
# score mean over 100 episode :  -214.07
# episode : 389/1000, score : -220, e : 0.39
# score mean over 100 episode :  -214.25
# episode : 390/1000, score : -223, e : 0.39
# score mean over 100 episode :  -214.68
# episode : 391/1000, score : -236, e : 0.39
# score mean over 100 episode :  -215.2
# episode : 392/1000, score : -255, e : 0.39
# score mean over 100 episode :  -216.08
# episode : 393/1000, score : -237, e : 0.39
# score mean over 100 episode :  -216.96
# episode : 394/1000, score : -229, e : 0.39
# score mean over 100 episode :  -217.35
# episode : 395/1000, score : -250, e : 0.39
# score mean over 100 episode :  -218.15
# episode : 396/1000, score : -226, e : 0.38
# score mean over 100 episode :  -218.59
# episode : 397/1000, score : -288, e : 0.38
# score mean over 100 episode :  -219.21
# episode : 398/1000, score : -222, e : 0.38
# score mean over 100 episode :  -219.18
# episode : 399/1000, score : -294, e : 0.38
# score mean over 100 episode :  -220.2
# episode : 400/1000, score : -294, e : 0.38
# score mean over 100 episode :  -221.32
# episode : 401/1000, score : -228, e : 0.38
# score mean over 100 episode :  -221.56
# episode : 402/1000, score : -253, e : 0.38
# score mean over 100 episode :  -222.1
# episode : 403/1000, score : -295, e : 0.37
# score mean over 100 episode :  -223.35
# episode : 404/1000, score : -280, e : 0.37
# score mean over 100 episode :  -223.99
# episode : 405/1000, score : -302, e : 0.37
# score mean over 100 episode :  -225.39

# %%
agent.set_test_mode(True)

sum_rewards = 0.0
nbr_episode = 100
for _ in range(nbr_episode):
    prod_line = Production_line(nbr_job_max, nbr_operation_max, nbr_machines, nbr_operator)
    job1 = Job("TEST1", 1,20000, nbr_operation_max)
    prod_line.add_job(job1)
    
    state = prod_line.get_state()
    done = False
    while not done:
        mask = prod_line.get_mask()
        action = agent.act(state,mask)
        next_state, reward, done = prod_line.step(action)
        
        agent.remember(state, action, reward, next_state, done)
        
        state = next_state
            
        sum_rewards += reward
        
    print(sum_rewards)
print('Mean evaluation return:', sum_rewards / nbr_episode)

# %%
planning = prod_line.get_gant_formated()

plan_df = pd.DataFrame()
for plan in planning:
    print(plan,"\n")
    df = pd.DataFrame(plan, columns =['Job','Machine', 'Operation', 'Start','Duration','Finish'])
    plan_df = pd.concat([plan_df, df], axis=0)

plan_df.reset_index(drop = True,inplace=True)

plan_df['Machine']= plan_df['Machine'].astype(str)
plan_df['Duration']= plan_df['Duration'].astype(int)

# %%
def visualize(results):
    
    operation_machine = {(1,1) : "broyage_poly_1",
                     (1,2) : "broyage_poly_2",
                     (2,3) : "tamisage_poly_3",
                     (3,4) : "mélange_4",
                     (3,5) : "mélange_5",
                     (4,6) : "extrusion_6",
                     (5,1) : "broyage_ug_1",
                     (5,2) : "broyage_ug_2",
                     (6,3) : "tamisage_ug_3",
                     (7,8) : "tween_8",
                     (8,7) : "combinaison_7",
                     (9,9) : "perry_9",
                     (10,10) : "sortie_lyo_10",
                     (11,11) : "capsulage_11",
                     (12,12) : "IV_12",
                     (13,13) : "envoi IRR_13",
                     (14,14) : "retour IRR_14"}
    
    schedule = results.copy()
    
    op_machine = []
    for row in schedule.iterrows():
        
        op = row[1]["Operation"]
        machine = row[1]["Machine"]
        op_machine.append(operation_machine[int(op),int(machine)])
    
    schedule["op_machine"] = op_machine
    
    JOBS = sorted(list(schedule['Job'].unique()))
    operation_machine_sorted = [value for key,value in operation_machine.items()][::-1]
    MACHINES = operation_machine_sorted
    makespan = schedule['Finish'].max()
    
    bar_style = {'alpha':1.0, 'lw':25, 'solid_capstyle':'butt'}
    text_style = {'color':'white', 'weight':'bold', 'ha':'center', 'va':'center'}
    colors = mpl.cm.Dark2.colors

    schedule.sort_values(by=['Job', 'Start'])
    schedule.set_index(['Job', 'op_machine'], inplace=True,append = True)
    
    fig, ax = plt.subplots(2,1, figsize=(12, 5+(len(JOBS)+len(MACHINES))/4))

    for jdx, j in enumerate(JOBS, 1):
        for mdx, m in enumerate(MACHINES, 1):
            for index,_,_ in schedule.index:
                if (index,j,m) in schedule.index:
                    

                    xs = schedule.loc[(index,j,m), 'Start']
                    xf = schedule.loc[(index,j,m), 'Finish']
                    ax[0].plot([xs, xf], [jdx]*2, c=colors[mdx%7], **bar_style)
                    ax[0].text((xs + xf)/2, jdx, m, **text_style)
                    ax[1].plot([xs, xf], [mdx]*2, c=colors[jdx%7], **bar_style)
                    ax[1].text((xs + xf)/2, mdx, j, **text_style)
                
    ax[0].set_title('Job Schedule')
    ax[0].set_ylabel('Job')
    ax[1].set_title('Machine Schedule')
    ax[1].set_ylabel('Machine')
    
    for idx, s in enumerate([JOBS, MACHINES]):
        ax[idx].set_ylim(0.5, len(s) + 0.5)
        ax[idx].set_yticks(range(1, 1 + len(s)))
        ax[idx].set_yticklabels(s)
        ax[idx].text(makespan, ax[idx].get_ylim()[0]-0.2, "{0:0.1f}".format(makespan), ha='center', va='top')
        ax[idx].plot([makespan]*2, ax[idx].get_ylim(), 'r--')
        ax[idx].set_xlabel('Time')
        ax[idx].grid(True)
        
    fig.tight_layout()
    
visualize(plan_df)
